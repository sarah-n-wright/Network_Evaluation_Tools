# %%
import pandas as pd
from network_evaluation_tools import gene_conversion_tools as gct

# %% [markdown]
# The following data was downloaded from CCSB and converted to edge list sifs for both symbol and entrez from the simple sifs given in both cases. No additional gene conversions were performed for these networks.

# %% [markdown]
# ## Load HI-II-14 (Human Interactome) Raw Data
# #### Source: http://interactome.dfci.harvard.edu/H_sapiens/download/HI-II-14.tsv
# #### File: 'HI-II-14'
# Downloaded: June 20, 2017
# Last Updated: Not Listed
# Proteome-scale map of the human binary interactome network generated by systematically screening Space-II associated with Rolland et al Cell 2014

# %%
wd = '/cellar/users/jkhuang/Data/Projects/Network_Analysis/Data/'
HumanInteractome_Raw = pd.read_csv(wd+'Network_Data_Raw/HI-II-14.tsv',sep='\t')
print 'Raw Interactions in HI-II-14:', len(HumanInteractome_Raw)
# Out:
# Raw Interactions in HI-II-14: 13944

# %%
# Convert table of interactions to edgelist (no scores given)
# Also no gene symbol conversion necessary because network is given in symbol format already
HumanInteractome_edgelist = HumanInteractome_Raw[['Symbol A', 'Symbol B']].values.tolist()
print 'Edges in HI-II-14:', len(HumanInteractome_edgelist)
# Out:
# Edges in HI-II-14: 13944

# %%
# Sort each edge representation for filtering
HumanInteractome_edgelist_sorted = [sorted(edge) for edge in HumanInteractome_edgelist]

# %%
# Filter edgelist for duplicate nodes and for self-edges
HumanInteractome_edgelist_filt = gct.filter_converted_edgelist(HumanInteractome_edgelist_sorted)
# Out:
# 13944 input edges
# 517 self-edges removed
# 0 edges with un-mapped genes removed
# 0 duplicate edges removed
# Edge list filtered: 0.02 seconds
# 13427 Edges remaining

# %%
# Save genelist to file
outdir = '/cellar/users/jkhuang/Data/Projects/Network_Analysis/Data/Network_SIFs_Symbol/'
gct.write_edgelist(HumanInteractome_edgelist_filt, outdir+'HumanInteractome_Symbol.sif')
# Out:
# Edge list saved: 0.02 seconds

# %%
import pandas as pd
x = pd.read_csv("~/Data/Network_Analysis/Network_Data_Raw/HI-II-14.tsv", sep="\t", header=None)

# %%
len(set(x[0]).union(set(x[1])))
# Out:
# 4182
